# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import sklearn 
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix

# %% [markdown]
# ## Import dataframes

# %%
train = pd.read_csv('data/train.csv')

# %%
train.head(5)
# Out:
#    id        date country              store             product  num_sold
# 0   0  2010-01-01  Canada  Discount Stickers   Holographic Goose       NaN
# 1   1  2010-01-01  Canada  Discount Stickers              Kaggle     973.0
# 2   2  2010-01-01  Canada  Discount Stickers        Kaggle Tiers     906.0
# 3   3  2010-01-01  Canada  Discount Stickers            Kerneler     423.0
# 4   4  2010-01-01  Canada  Discount Stickers  Kerneler Dark Mode     491.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230130 entries, 0 to 230129
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        230130 non-null  int64
#  1   date      230130 non-null  object
#  2   country   230130 non-null  object
#  3   store     230130 non-null  object
#  4   product   230130 non-null  object
#  5   num_sold  221259 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 10.5+ MB

# %%
train = train.fillna(0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230130 entries, 0 to 230129
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        230130 non-null  int64
#  1   date      230130 non-null  object
#  2   country   230130 non-null  object
#  3   store     230130 non-null  object
#  4   product   230130 non-null  object
#  5   num_sold  230130 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 10.5+ MB

# %%
train.country.unique()
# Out:
# array(['Canada', 'Finland', 'Italy', 'Kenya', 'Norway', 'Singapore'],
#       dtype=object)

# %%
train['product'].unique()
# Out:
# array(['Holographic Goose', 'Kaggle', 'Kaggle Tiers', 'Kerneler',
#        'Kerneler Dark Mode'], dtype=object)

# %%
scatter_matrix(train, figsize=(15,10), alpha=0.9)
# Out:
# array([[<Axes: xlabel='id', ylabel='id'>,
#         <Axes: xlabel='num_sold', ylabel='id'>],
#        [<Axes: xlabel='id', ylabel='num_sold'>,
#         <Axes: xlabel='num_sold', ylabel='num_sold'>]], dtype=object)
